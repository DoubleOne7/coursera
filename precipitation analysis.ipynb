# %% [markdown]
# # Description
# The notebook analyzes and visualzes weight data

# %%
# The code was removed by Watson Studio for sharing.
# Out:
#    weightChange        group
# 0          -8.4  Self-Guided
# 1          -6.4  Self-Guided
# 2           4.4  Self-Guided
# 3          -4.6  Self-Guided
# 4          -4.2  Self-Guided
